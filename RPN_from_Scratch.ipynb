#   inflating: trainA_original_700/0000f77c-6257be58.jpg
#   inflating: trainA_original_700/00abf44e-421f6ed7.jpg
#   inflating: trainA_original_700/00a2f5b6-d4217a96.jpg
#   inflating: trainA_original_700/0a0c3694-f3444902.jpg
#   inflating: trainA_original_700/00a2e3ca-5c856cde.jpg
#   inflating: trainA_original_700/0000f77c-62c2a288.jpg
#   inflating: trainA_original_700/000e0252-8523a4a9.jpg
#   inflating: trainA_original_700/00c87627-b7f6f46c.jpg
#   inflating: trainA_original_700/00d18b13-52d3e4c4.jpg
#   inflating: trainA_original_700/00ac3256-0f8e2cda.jpg
#   inflating: trainA_original_700/000f157f-dab3a407.jpg
#   inflating: trainA_original_700/00a9cd6b-b39be004.jpg
#   inflating: trainA_original_700/00beeb02-50440dcd.jpg
#   inflating: trainA_original_700/0000f77c-cb820c98.jpg
#   inflating: trainA_original_700/000f8d37-d4c09a0f.jpg
#   inflating: trainA_original_700/00b04b30-2e874876.jpg
#   inflating: trainA_original_700/00a0f008-3c67908e.jpg
#   inflating: trainA_original_700/00b1dfed-a89dbe2b.jpg
#   inflating: trainA_original_700/00a1176f-5121b501.jpg
#   inflating: trainA_original_700/00d77344-9fe25620.jpg
#   inflating: trainA_original_700/000d4f89-3bcbe37a.jpg

# %%
# !unzip 'trainA_norm_700.zip' # image tensors resized to [3, 223, 223]
# Out:
# unzip:  cannot find or open trainA_norm_700.zip, trainA_norm_700.zip.zip or trainA_norm_700.zip.ZIP.

# %% [markdown]
# ## Labeling

# %%
def extract_first_n_labels(json_file_path, n):
    labels = []
    with open(json_file_path, 'rb') as f:
        parser = ijson.items(f, 'item')
        for i, item in enumerate(parser):
            if i >= n: # ensuring only labels of n images are extracted from the json file
                break
            # Filter out objects with poly2d labels and keep only box2d labels
            filtered_labels = [
                {
                    "category": label_item.get("category"),
                    "box2d": label_item.get("box2d")
                }
                for label_item in item.get("labels", [])
                if "box2d" in label_item # only get label_item with box2d
            ]
            labels.append({
                "name": item.get("name"),
                "timestamp": item.get("timestamp"),
                "labels": filtered_labels
            })
    return labels

json_file_path = 'bdd100k_labels_images_train.json'

# Extract the first 700 labels
first_700_labels = extract_first_n_labels(json_file_path, 700)

# %%
# Print a few labels to verify
for i, label in enumerate(first_700_labels[:2]):
    print(f"Label {i + 1}:")
    print(f"  Name: {label['name']}")
    print(f"  Timestamp: {label['timestamp']}")
    print("  Labels:")
    for obj in label['labels']:
        print(f"    Category: {obj['category']}")
        print(f"    2D Box: {obj['box2d']}")
    print("-" * 40)
# Out:
# Label 1:
#   Name: 0000f77c-6257be58.jpg
#   Timestamp: 10000
#   Labels:
#     Category: traffic light
#     2D Box: {'x1': Decimal('1125.902264'), 'y1': Decimal('133.184488'), 'x2': Decimal('1156.978645'), 'y2': Decimal('210.875445')}
#     Category: traffic light
#     2D Box: {'x1': Decimal('1156.978645'), 'y1': Decimal('136.637417'), 'x2': Decimal('1191.50796'), 'y2': Decimal('210.875443')}
#     Category: traffic sign
#     2D Box: {'x1': Decimal('1101.731743'), 'y1': Decimal('211.122087'), 'x2': Decimal('1170.79037'), 'y2': Decimal('233.566141')}
#     Category: traffic sign
#     2D Box: {'x1': 0, 'y1': Decimal('0.246631'), 'x2': Decimal('100.381647'), 'y2': Decimal('122.825696')}
#     Category: car
#     2D Box: {'x1': Decimal('45.240919'), 'y1': Decimal('254.530367'), 'x2': Decimal('357.805838'), 'y2': Decimal('487.906215')}
#     Category: car
#     2D Box: {'x1': Decimal('507.82755'), 'y1': Decimal('221.727518'), 'x2': Decimal('908.367588'), 'y2': Decimal('442.715126')}
#     Category: traffic sign
#     2D Box: {'x1': Decimal('0.156955'), 'y1': Decimal('0.809282'), 'x2': Decimal('102.417429'), 'y2': Decimal('133.411856')}
# ----------------------------------------
# Label 2:
#   Name: 0000f77c-62c2a288.jpg
#   Timestamp: 10000
#   Labels:
#     Category: traffic sign
#     2D Box: {'x1': Decimal('250.549246'), 'y1': Decimal('294.619798'), 'x2': Decimal('308.085801'), 'y2': Decimal('357.05308')}
#     Category: traffic sign
#     2D Box: {'x1': Decimal('206.478694'), 'y1': Decimal('299.516526'), 'x2': Decimal('221.16888'), 'y2': Decimal('321.551802')}
#     Category: traffic sign
#     2D Box: {'x1': Decimal('924.665474'), 'y1': Decimal('286.866651'), 'x2': Decimal('936.907294'), 'y2': Decimal('297.884289')}
#     Category: person
#     2D Box: {'x1': Decimal('423.158909'), 'y1': Decimal('336.241987'), 'x2': Decimal('434.176547'), 'y2': Decimal('358.277263')}
#     Category: person
#     2D Box: {'x1': Decimal('563.939839'), 'y1': Decimal('324.000165'), 'x2': Decimal('573.733294'), 'y2': Decimal('348.483804')}
#     Category: person
#     2D Box: {'x1': Decimal('656.977672'), 'y1': Decimal('315.838956'), 'x2': Decimal('666.771127'), 'y2': Decimal('345.219323')}
# ----------------------------------------

# %% [markdown]
# ## Preparing Datasets

# %%
import os
import torch
from torch.utils.data import Dataset, random_split
from PIL import Image
import torchvision.transforms as transforms
from decimal import Decimal

def standardize_filename(path_or_name):
    """
    Convert something like:
      - "folder/subfolder/abcd123.jpg.pt" -> "abcd123"
      - "abcd123.png" -> "abcd123"
    i.e. strip directories & remove extensions.
    """
    # Remove any directories
    base = os.path.basename(path_or_name)
    # Split off the first extension (e.g. ".pt" or ".jpg")
    base, _ = os.path.splitext(base)
    return base  # e.g. "abcd123.jpg" or just "abcd123" if there were two extensions

class CustomDataset(Dataset):
    def __init__(self, image_dir, labels, pt_dir='pt_files', max_boxes=16):
        self.image_dir = image_dir
        self.pt_dir = pt_dir
        self.image_files = sorted([os.path.join(image_dir, f)
                                   for f in os.listdir(image_dir)
                                   if f.lower().endswith(('.jpg', '.png', '.jpeg'))])
        self.max_boxes = max_boxes  # Maximum number of bounding boxes per image

        # Create the directory for .pt files if it doesn't exist
        os.makedirs(self.pt_dir, exist_ok=True)

        # Build a dict from label "base name" -> the full label dictionary
        self.label_dict = {}
        for item in labels:
            key = standardize_filename(item["name"])
            self.label_dict[key] = item

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
      # Get the image path
      image_path = self.image_files[idx]
      transform = transforms.Compose([
          transforms.PILToTensor(),  # Keeps pixel values in range [0, 255]
      ])

      # Define the path for the .pt file
      pt_path = os.path.join(
          self.pt_dir,
          os.path.basename(image_path)
          .replace('.jpg', '.pt')
          .replace('.png', '.pt')
          .replace('.jpeg', '.pt')
      )

      # Check if the .pt file already exists
      if os.path.exists(pt_path):
          print(f"Loading .pt file: {pt_path}")
          image_tensor = torch.load(pt_path)
      else:
          print(f"Saving .pt file: {pt_path}")
          # Load the image and convert it to a tensor
          image = Image.open(image_path).convert('RGB')
          image_tensor = transform(image).float()  # Convert to float for normalization if needed
          torch.save(image_tensor, pt_path)

      # Standardize the base name so it lines up with your JSON
      base_key = standardize_filename(image_path)

      # Debug: Print the base_key to verify it matches the label_dict keys
      print(f"Base key for image {idx}: {base_key}")

      matched_label = self.label_dict.get(base_key, None)
      if matched_label is None or "labels" not in matched_label:
          # Return empty boxes and labels
          return image_tensor, {
              "boxes": torch.zeros((self.max_boxes, 4), dtype=torch.float32),  # Pad to max_boxes
              "labels": torch.zeros((self.max_boxes,), dtype=torch.int64),     # Pad to max_boxes
              "names": []
          }

      boxes = []
      class_labels_str = []  # will store strings like "car", "person", etc.
      for obj in matched_label["labels"]:
          if "box2d" in obj:
              b2d = obj["box2d"]
              # Convert Decimal values to float
              x1 = float(b2d["x1"])
              y1 = float(b2d["y1"])
              x2 = float(b2d["x2"])
              y2 = float(b2d["y2"])
              boxes.append([x1, y1, x2, y2])
              class_labels_str.append(obj["category"])  # e.g. "car", "person", etc.

      if len(boxes) == 0:
          # Return empty boxes and labels
          return image_tensor, {
              "boxes": torch.zeros((self.max_boxes, 4), dtype=torch.float32),  # Pad to max_boxes
              "labels": torch.zeros((self.max_boxes,), dtype=torch.int64),     # Pad to max_boxes
              "names": []
          }

      # Convert boxes to tensor
      boxes_tensor = torch.tensor(boxes, dtype=torch.float32)

      # Truncate or pad boxes and labels to a fixed size (max_boxes)
      if boxes_tensor.shape[0] > self.max_boxes:
          # Truncate excess boxes
          boxes_tensor = boxes_tensor[:self.max_boxes]
          class_labels_str = class_labels_str[:self.max_boxes]
      elif boxes_tensor.shape[0] < self.max_boxes:
          # Pad with zeros
          padding = torch.zeros((self.max_boxes - boxes_tensor.shape[0], 4), dtype=torch.float32)
          boxes_tensor = torch.cat([boxes_tensor, padding], dim=0)
          class_labels_str.extend([""] * (self.max_boxes - len(class_labels_str)))  # Pad names with empty strings

      # Convert labels to tensor
      labels_tensor = torch.tensor([1] * len(class_labels_str), dtype=torch.int64)

      # Return image + label dict
      return image_tensor, {
          "boxes": boxes_tensor,
          "labels": labels_tensor,
          "names": class_labels_str  # <--- store string names here
      }

# Specify the path to the directory containing the original images
image_dir = 'trainA_original_700'  # Replace with your actual directory

# Define the labels for your images (update as necessary)
# Example: Provide meaningful labels for each image
json_file_path = 'bdd100k_labels_images_train.json'
first_700_labels = extract_first_n_labels(json_file_path, 700)

# Specify the directory to save the .pt files
pt_dir = 'trainA_testing3'

# Create the dataset
dataset = CustomDataset(image_dir, first_700_labels, pt_dir, max_boxes=16)
# Iterate over the dataset to process and save the images as .pt files
for i in range(len(dataset)):
    _ = dataset[i]
# Out:
# Saving .pt file: trainA_testing3/0000f77c-6257be58.pt
# Base key for image 0: 0000f77c-6257be58
# Saving .pt file: trainA_testing3/0000f77c-62c2a288.pt
# Base key for image 1: 0000f77c-62c2a288
# Saving .pt file: trainA_testing3/0000f77c-cb820c98.pt
# Base key for image 2: 0000f77c-cb820c98
# Saving .pt file: trainA_testing3/000d4f89-3bcbe37a.pt
# Base key for image 3: 000d4f89-3bcbe37a
# Saving .pt file: trainA_testing3/000e0252-8523a4a9.pt
# Base key for image 4: 000e0252-8523a4a9
# Saving .pt file: trainA_testing3/000f157f-dab3a407.pt
# Base key for image 5: 000f157f-dab3a407
# Saving .pt file: trainA_testing3/000f8d37-d4c09a0f.pt
# Base key for image 6: 000f8d37-d4c09a0f
# Saving .pt file: trainA_testing3/00a0f008-3c67908e.pt
# Base key for image 7: 00a0f008-3c67908e
# Saving .pt file: trainA_testing3/00a0f008-a315437f.pt
# Base key for image 8: 00a0f008-a315437f
# Saving .pt file: trainA_testing3/00a1176f-0652080e.pt
# Base key for image 9: 00a1176f-0652080e
# Saving .pt file: trainA_testing3/00a1176f-5121b501.pt
# Base key for image 10: 00a1176f-5121b501
# Saving .pt file: trainA_testing3/00a2e3ca-5c856cde.pt
# Base key for image 11: 00a2e3ca-5c856cde
# Saving .pt file: trainA_testing3/00a2e3ca-62992459.pt
# Base key for image 12: 00a2e3ca-62992459
# Saving .pt file: trainA_testing3/00a2f5b6-d4217a96.pt
# Base key for image 13: 00a2f5b6-d4217a96
# Saving .pt file: trainA_testing3/00a395fe-d60c0b47.pt
# Base key for image 14: 00a395fe-d60c0b47
# Saving .pt file: trainA_testing3/00a820ef-2b98dcf5.pt
# Base key for image 15: 00a820ef-2b98dcf5
# Saving .pt file: trainA_testing3/00a820ef-98a12e22.pt
# Base key for image 16: 00a820ef-98a12e22
# Saving .pt file: trainA_testing3/00a820ef-d655700e.pt
# Base key for image 17: 00a820ef-d655700e
# Saving .pt file: trainA_testing3/00a9cd6b-b39be004.pt
# Base key for image 18: 00a9cd6b-b39be004
# Saving .pt file: trainA_testing3/00abd8a7-ecd6fc56.pt
# Base key for image 19: 00abd8a7-ecd6fc56
# Saving .pt file: trainA_testing3/00abf44e-04004ca0.pt
# Base key for image 20: 00abf44e-04004ca0
# Saving .pt file: trainA_testing3/00abf44e-421f6ed7.pt
# Base key for image 21: 00abf44e-421f6ed7
# Saving .pt file: trainA_testing3/00ac3256-0f8e2cda.pt
# Base key for image 22: 00ac3256-0f8e2cda
# Saving .pt file: trainA_testing3/00ad8a92-c4851839.pt
# Base key for image 23: 00ad8a92-c4851839
# Saving .pt file: trainA_testing3/00adbb3f-7757d4ea.pt
# Base key for image 24: 00adbb3f-7757d4ea
# Saving .pt file: trainA_testing3/00afa5b2-c14a542f.pt
# Base key for image 25: 00afa5b2-c14a542f
# Saving .pt file: trainA_testing3/00b04b30-2e874876.pt
# Base key for image 26: 00b04b30-2e874876
# Saving .pt file: trainA_testing3/00b04b30-501822fa.pt
# Saving .pt file: trainA_testing3/00eb41b2-6bbff2ca.pt
# Base key for image 55: 00eb41b2-6bbff2ca
# Saving .pt file: trainA_testing3/00ecf963-bea6bf0f.pt
# Base key for image 56: 00ecf963-bea6bf0f
# Saving .pt file: trainA_testing3/00ed2e85-82bdd22b.pt
# Base key for image 57: 00ed2e85-82bdd22b
# Saving .pt file: trainA_testing3/00ed2e85-95394dfd.pt
# Base key for image 58: 00ed2e85-95394dfd
# Saving .pt file: trainA_testing3/00f0dd0f-1adbde75.pt
# Base key for image 59: 00f0dd0f-1adbde75
# Saving .pt file: trainA_testing3/00f0dd0f-5e9c9557.pt
# Base key for image 60: 00f0dd0f-5e9c9557
# Saving .pt file: trainA_testing3/00f42f6b-5a20a4d2.pt
# Base key for image 61: 00f42f6b-5a20a4d2
# Saving .pt file: trainA_testing3/00f42f6b-699a498c.pt
# Base key for image 62: 00f42f6b-699a498c
# Saving .pt file: trainA_testing3/00f42f6b-b1ca1f6c.pt
# Base key for image 63: 00f42f6b-b1ca1f6c
# Saving .pt file: trainA_testing3/00f7eac8-5193d600.pt
# Base key for image 64: 00f7eac8-5193d600
# Saving .pt file: trainA_testing3/00f89335-1825f637.pt
# Base key for image 65: 00f89335-1825f637
# Saving .pt file: trainA_testing3/00f89335-2ef7949d.pt
# Base key for image 66: 00f89335-2ef7949d
# Saving .pt file: trainA_testing3/00f8f875-bad0295f.pt
# Base key for image 67: 00f8f875-bad0295f
# Saving .pt file: trainA_testing3/00fba75b-5d18da26.pt
# Base key for image 68: 00fba75b-5d18da26
# Saving .pt file: trainA_testing3/00fbb190-8834f55b.pt
# Base key for image 69: 00fbb190-8834f55b
# Saving .pt file: trainA_testing3/00fc910e-bce87172.pt
# Base key for image 70: 00fc910e-bce87172
# Saving .pt file: trainA_testing3/00fcfec9-7ba5dabf.pt
# Base key for image 71: 00fcfec9-7ba5dabf
# Saving .pt file: trainA_testing3/00fcfec9-8accd82b.pt
# Base key for image 72: 00fcfec9-8accd82b
# Saving .pt file: trainA_testing3/0a022bf4-abaf66af.pt
# Base key for image 73: 0a022bf4-abaf66af
# Saving .pt file: trainA_testing3/0a022bf4-be711762.pt
# Base key for image 74: 0a022bf4-be711762
# Saving .pt file: trainA_testing3/0a022bf4-fb62ebb1.pt
# Base key for image 75: 0a022bf4-fb62ebb1
# Saving .pt file: trainA_testing3/0a0379a5-2a18e95b.pt
# Base key for image 76: 0a0379a5-2a18e95b
# Saving .pt file: trainA_testing3/0a0379a5-3870b241.pt
# Base key for image 77: 0a0379a5-3870b241
# Saving .pt file: trainA_testing3/0a0379a5-d2e2ba43.pt
# Base key for image 78: 0a0379a5-d2e2ba43
# Saving .pt file: trainA_testing3/0a05a47b-2342eda4.pt
# Base key for image 79: 0a05a47b-2342eda4
# Saving .pt file: trainA_testing3/0a05a6bd-cd1ff04a.pt
# Base key for image 80: 0a05a6bd-cd1ff04a
# Saving .pt file: trainA_testing3/0a06d3bc-7f823a5a.pt
# Base key for image 81: 0a06d3bc-7f823a5a
# Saving .pt file: trainA_testing3/0a07abbf-5eeee19d.pt
# Base key for image 82: 0a07abbf-5eeee19d
# Saving .pt file: trainA_testing3/0a0a0b1a-27d9fc44.pt
# Base key for image 83: 0a0a0b1a-27d9fc44
# Saving .pt file: trainA_testing3/0a0a0b1a-7c39d841.pt
# Base key for image 84: 0a0a0b1a-7c39d841
# Saving .pt file: trainA_testing3/0a0c3694-24b5193a.pt
# Base key for image 85: 0a0c3694-24b5193a
# Saving .pt file: trainA_testing3/0a0c3694-24fe9c8d.pt
# Base key for image 86: 0a0c3694-24fe9c8d
# Saving .pt file: trainA_testing3/0a0c3694-37864ee7.pt
# Base key for image 87: 0a0c3694-37864ee7
# Saving .pt file: trainA_testing3/0a0c3694-487a156f.pt
# Base key for image 88: 0a0c3694-487a156f
# Saving .pt file: trainA_testing3/0a0c3694-4cc8b0e3.pt
# Base key for image 89: 0a0c3694-4cc8b0e3
# Saving .pt file: trainA_testing3/0a0c3694-54476ae3.pt
# Base key for image 90: 0a0c3694-54476ae3
# Saving .pt file: trainA_testing3/0a0c3694-f3444902.pt
# Base key for image 91: 0a0c3694-f3444902
# Saving .pt file: trainA_testing3/0a0ceca1-4148e482.pt
# Base key for image 92: 0a0ceca1-4148e482
# Saving .pt file: trainA_testing3/0a0d6e22-f6446b68.pt
# Base key for image 93: 0a0d6e22-f6446b68
# Saving .pt file: trainA_testing3/0a0eaeaf-9ad0c6dd.pt
# Base key for image 94: 0a0eaeaf-9ad0c6dd
# Saving .pt file: trainA_testing3/0a14a567-fdd08dd2.pt
# Base key for image 95: 0a14a567-fdd08dd2
# Saving .pt file: trainA_testing3/0a172b0e-136b7a63.pt
# Base key for image 96: 0a172b0e-136b7a63
# Saving .pt file: trainA_testing3/0a172b0e-2af0d158.pt
# Base key for image 97: 0a172b0e-2af0d158
# Saving .pt file: trainA_testing3/0a176daf-cf60d027.pt
# Base key for image 98: 0a176daf-cf60d027
# Saving .pt file: trainA_testing3/0a176daf-d509ae60.pt
# Base key for image 99: 0a176daf-d509ae60
# Saving .pt file: trainA_testing3/0a19489c-120e718b.pt
# Base key for image 100: 0a19489c-120e718b
# Saving .pt file: trainA_testing3/0a19489c-498fdc3f.pt
# Base key for image 101: 0a19489c-498fdc3f
# Saving .pt file: trainA_testing3/0a19489c-e9e406be.pt
# Base key for image 102: 0a19489c-e9e406be
# Saving .pt file: trainA_testing3/0a1f4fce-f9cac880.pt
# Base key for image 103: 0a1f4fce-f9cac880
# Saving .pt file: trainA_testing3/0a1fca63-8fb09c39.pt
# Base key for image 104: 0a1fca63-8fb09c39
# Saving .pt file: trainA_testing3/0a237a03-54739d88.pt
# Base key for image 105: 0a237a03-54739d88
# Saving .pt file: trainA_testing3/0a2387c5-e749100d.pt
# Base key for image 106: 0a2387c5-e749100d
# Saving .pt file: trainA_testing3/0a2804db-65f4ffa1.pt
# Base key for image 107: 0a2804db-65f4ffa1
# Saving .pt file: trainA_testing3/0a2804db-677b1b1d.pt
# Base key for image 108: 0a2804db-677b1b1d
# Saving .pt file: trainA_testing3/0a2804db-68acbf2b.pt
# Base key for image 109: 0a2804db-68acbf2b
# Saving .pt file: trainA_testing3/0a2804db-72d1407f.pt
# Base key for image 110: 0a2804db-72d1407f
# Saving .pt file: trainA_testing3/0a2804db-af7001a6.pt
# Base key for image 111: 0a2804db-af7001a6
# Saving .pt file: trainA_testing3/0a29cfd8-8899f383.pt
# Base key for image 112: 0a29cfd8-8899f383
# Saving .pt file: trainA_testing3/0a2b7f2a-bc0ce8da.pt
# Base key for image 113: 0a2b7f2a-bc0ce8da
# Saving .pt file: trainA_testing3/0a2cc187-8d6ab554.pt
# Base key for image 114: 0a2cc187-8d6ab554
# Saving .pt file: trainA_testing3/0a31955c-88fe50d9.pt
# Base key for image 115: 0a31955c-88fe50d9
# Saving .pt file: trainA_testing3/0a342bb9-bfc9eccd.pt
# Base key for image 116: 0a342bb9-bfc9eccd
# Saving .pt file: trainA_testing3/0a348d6a-9f9be6a9.pt
# Base key for image 117: 0a348d6a-9f9be6a9
# Saving .pt file: trainA_testing3/0a43ee66-24687d98.pt
# Base key for image 118: 0a43ee66-24687d98
# Saving .pt file: trainA_testing3/0a43ee66-9617d2ce.pt
# Base key for image 119: 0a43ee66-9617d2ce
# Saving .pt file: trainA_testing3/0a4411cf-e30aa257.pt
# Base key for image 120: 0a4411cf-e30aa257
# Saving .pt file: trainA_testing3/0a4492aa-d7472a91.pt
# Base key for image 121: 0a4492aa-d7472a91
# Saving .pt file: trainA_testing3/0a4773b8-309d2347.pt
# Base key for image 122: 0a4773b8-309d2347
# Saving .pt file: trainA_testing3/0a4773b8-ff24b5af.pt
# Base key for image 123: 0a4773b8-ff24b5af
# Saving .pt file: trainA_testing3/0a48c5ed-38e5a6e1.pt
# Base key for image 124: 0a48c5ed-38e5a6e1
# Saving .pt file: trainA_testing3/0a493f24-352f747e.pt
# Base key for image 125: 0a493f24-352f747e
# Saving .pt file: trainA_testing3/0a49dd06-9c0fffaf.pt
# Base key for image 126: 0a49dd06-9c0fffaf
# Saving .pt file: trainA_testing3/0a4d348a-7e574e21.pt
# Base key for image 127: 0a4d348a-7e574e21
# Saving .pt file: trainA_testing3/0a4e87a0-b52d82b5.pt
# Base key for image 128: 0a4e87a0-b52d82b5
# Saving .pt file: trainA_testing3/0a50c21f-7ce4c307.pt
# Base key for image 129: 0a50c21f-7ce4c307
# Saving .pt file: trainA_testing3/0a50c21f-8dbacc21.pt
# Base key for image 130: 0a50c21f-8dbacc21
# Saving .pt file: trainA_testing3/0a514790-e4c8e3e3.pt
# Base key for image 131: 0a514790-e4c8e3e3
# Saving .pt file: trainA_testing3/0a53c48b-86fda2c8.pt
# Base key for image 132: 0a53c48b-86fda2c8
# Saving .pt file: trainA_testing3/0a56c2e8-1290ac29.pt
# Base key for image 133: 0a56c2e8-1290ac29
# Saving .pt file: trainA_testing3/0a56c2e8-e46ca9b7.pt
# Base key for image 134: 0a56c2e8-e46ca9b7
# Saving .pt file: trainA_testing3/0a594137-66f7cbe8.pt
# Base key for image 135: 0a594137-66f7cbe8
# Saving .pt file: trainA_testing3/0a594137-6e8ba4a6.pt
# Saving .pt file: trainA_testing3/0ac2cd53-8287aaa9.pt
# Base key for image 218: 0ac2cd53-8287aaa9
# Saving .pt file: trainA_testing3/0ac3cbf4-07c64adc.pt
# Base key for image 219: 0ac3cbf4-07c64adc
# Saving .pt file: trainA_testing3/0ac3cbf4-2bbc1544.pt
# Base key for image 220: 0ac3cbf4-2bbc1544
# Saving .pt file: trainA_testing3/0ac3cbf4-73c76d25.pt
# Base key for image 221: 0ac3cbf4-73c76d25
# Saving .pt file: trainA_testing3/0ac3cbf4-a764f88c.pt
# Base key for image 222: 0ac3cbf4-a764f88c
# Saving .pt file: trainA_testing3/0ac3cbf4-ce89456d.pt
# Base key for image 223: 0ac3cbf4-ce89456d
# Saving .pt file: trainA_testing3/0ac47490-900fb1f7.pt
# Base key for image 224: 0ac47490-900fb1f7
# Saving .pt file: trainA_testing3/0ac58985-f1f6e541.pt
# Base key for image 225: 0ac58985-f1f6e541
# Saving .pt file: trainA_testing3/0ac641c6-43580bb6.pt
# Base key for image 226: 0ac641c6-43580bb6
# Saving .pt file: trainA_testing3/0ac7df0b-e18be171.pt
# Base key for image 227: 0ac7df0b-e18be171
# Saving .pt file: trainA_testing3/0acc0c71-c476dd2a.pt
# Base key for image 228: 0acc0c71-c476dd2a
# Saving .pt file: trainA_testing3/0acc0c71-fb703219.pt
# Base key for image 229: 0acc0c71-fb703219
# Saving .pt file: trainA_testing3/0accdaac-8ac51d5c.pt
# Base key for image 230: 0accdaac-8ac51d5c
# Saving .pt file: trainA_testing3/0accdaac-c56e44be.pt
# Base key for image 231: 0accdaac-c56e44be
# Saving .pt file: trainA_testing3/0acd25d7-3b21984a.pt
# Base key for image 232: 0acd25d7-3b21984a
# Saving .pt file: trainA_testing3/0ace96c3-48481887.pt
# Base key for image 233: 0ace96c3-48481887
# Saving .pt file: trainA_testing3/0ace96c3-8dc21565.pt
# Base key for image 234: 0ace96c3-8dc21565
# Saving .pt file: trainA_testing3/0acec6f7-40ab585c.pt
# Base key for image 235: 0acec6f7-40ab585c
# Saving .pt file: trainA_testing3/0acfc9a2-a7df0317.pt
# Base key for image 236: 0acfc9a2-a7df0317
# Saving .pt file: trainA_testing3/0ad051b9-9a51e0bf.pt
# Base key for image 237: 0ad051b9-9a51e0bf
# Saving .pt file: trainA_testing3/0ad5bdee-b3226dbc.pt
# Base key for image 238: 0ad5bdee-b3226dbc
# Saving .pt file: trainA_testing3/0ad67e35-2b01de49.pt
# Base key for image 239: 0ad67e35-2b01de49
# Saving .pt file: trainA_testing3/0ad67e35-56935819.pt
# Base key for image 240: 0ad67e35-56935819
# Saving .pt file: trainA_testing3/0ad67e35-8628df27.pt
# Base key for image 241: 0ad67e35-8628df27
# Saving .pt file: trainA_testing3/0ad67e35-a0dcb000.pt
# Base key for image 242: 0ad67e35-a0dcb000
# Saving .pt file: trainA_testing3/0ad67e35-cc83d0f5.pt
# Base key for image 243: 0ad67e35-cc83d0f5
# Saving .pt file: trainA_testing3/0add4446-2fb7b347.pt
# Base key for image 244: 0add4446-2fb7b347
# Saving .pt file: trainA_testing3/0adeb232-4ceba0d3.pt
# Base key for image 245: 0adeb232-4ceba0d3
# Saving .pt file: trainA_testing3/0ae18b49-b34d0abc.pt
# Base key for image 246: 0ae18b49-b34d0abc
# Saving .pt file: trainA_testing3/0ae18b49-e911c6b6.pt
# Base key for image 247: 0ae18b49-e911c6b6
# Saving .pt file: trainA_testing3/0ae65b30-09274ba7.pt
# Base key for image 248: 0ae65b30-09274ba7
# Saving .pt file: trainA_testing3/0ae8208c-1b20bbc5.pt
# Base key for image 249: 0ae8208c-1b20bbc5
# Saving .pt file: trainA_testing3/0aec42a1-17a32b5a.pt
# Base key for image 250: 0aec42a1-17a32b5a
# Saving .pt file: trainA_testing3/0aece855-7c6111b0.pt
# Base key for image 251: 0aece855-7c6111b0
# Saving .pt file: trainA_testing3/0af07355-56e42b91.pt
# Base key for image 252: 0af07355-56e42b91
# Saving .pt file: trainA_testing3/0af07355-d4bea79c.pt
# Base key for image 253: 0af07355-d4bea79c
# Saving .pt file: trainA_testing3/0af6039a-f3c91319.pt
# Base key for image 254: 0af6039a-f3c91319
# Saving .pt file: trainA_testing3/0af99ed6-252c770e.pt
# Base key for image 255: 0af99ed6-252c770e
# Saving .pt file: trainA_testing3/0af99ed6-441b82fd.pt
# Base key for image 256: 0af99ed6-441b82fd
# Saving .pt file: trainA_testing3/0afb7706-1fddf2a5.pt
# Base key for image 257: 0afb7706-1fddf2a5
# Saving .pt file: trainA_testing3/0afc7cb8-a6c21939.pt
# Base key for image 258: 0afc7cb8-a6c21939
# Saving .pt file: trainA_testing3/0b04bdff-d3fe6412.pt
# Base key for image 259: 0b04bdff-d3fe6412
# Saving .pt file: trainA_testing3/0b05f0b9-6fb236ee.pt
# Base key for image 260: 0b05f0b9-6fb236ee
# Saving .pt file: trainA_testing3/0b086427-1167d9f1.pt
# Base key for image 261: 0b086427-1167d9f1
# Saving .pt file: trainA_testing3/0b098a3e-492efacf.pt
# Base key for image 262: 0b098a3e-492efacf
# Saving .pt file: trainA_testing3/0b099136-a2bb901a.pt
# Base key for image 263: 0b099136-a2bb901a
# Saving .pt file: trainA_testing3/0b099136-a9ec5a5f.pt
# Base key for image 264: 0b099136-a9ec5a5f
# Saving .pt file: trainA_testing3/0b099136-bc2d1314.pt
# Base key for image 265: 0b099136-bc2d1314
# Saving .pt file: trainA_testing3/0b099136-c7c00345.pt
# Base key for image 266: 0b099136-c7c00345
# Saving .pt file: trainA_testing3/0b0b8474-ef07f89f.pt
# Base key for image 267: 0b0b8474-ef07f89f
# Saving .pt file: trainA_testing3/0b0b93b3-5bb0e887.pt
# Base key for image 268: 0b0b93b3-5bb0e887
# Saving .pt file: trainA_testing3/0b0c5455-b2513b86.pt
# Base key for image 269: 0b0c5455-b2513b86
# Saving .pt file: trainA_testing3/0b0db4da-610e258e.pt
# Base key for image 270: 0b0db4da-610e258e
# Saving .pt file: trainA_testing3/0b0e1eb1-399a3892.pt
# Base key for image 271: 0b0e1eb1-399a3892
# Saving .pt file: trainA_testing3/0b0e7ddf-43c07f1b.pt
# Base key for image 272: 0b0e7ddf-43c07f1b
# Saving .pt file: trainA_testing3/0b127ac1-9526fdd9.pt
# Base key for image 273: 0b127ac1-9526fdd9
# Saving .pt file: trainA_testing3/0b13e9d0-aaf0cc7e.pt
# Base key for image 274: 0b13e9d0-aaf0cc7e
# Saving .pt file: trainA_testing3/0b152984-cc8e102f.pt
# Base key for image 275: 0b152984-cc8e102f
# Saving .pt file: trainA_testing3/0b1721b1-950fddff.pt
# Base key for image 276: 0b1721b1-950fddff
# Saving .pt file: trainA_testing3/0b1899db-35fc45a1.pt
# Base key for image 277: 0b1899db-35fc45a1
# Saving .pt file: trainA_testing3/0b1afd00-1f158b3e.pt
# Base key for image 278: 0b1afd00-1f158b3e
# Saving .pt file: trainA_testing3/0b1afd00-2bb20983.pt
# Base key for image 279: 0b1afd00-2bb20983
# Saving .pt file: trainA_testing3/0b1b4391-7e947e1a.pt
# Base key for image 280: 0b1b4391-7e947e1a
# Saving .pt file: trainA_testing3/0b1b4391-b4a323f8.pt
# Base key for image 281: 0b1b4391-b4a323f8
# Saving .pt file: trainA_testing3/0b1b5202-1d080218.pt
# Base key for image 282: 0b1b5202-1d080218
# Saving .pt file: trainA_testing3/0b1beb15-18d74ac1.pt
# Base key for image 283: 0b1beb15-18d74ac1
# Saving .pt file: trainA_testing3/0b1bf6f2-ddbbc330.pt
# Base key for image 284: 0b1bf6f2-ddbbc330
# Saving .pt file: trainA_testing3/0b228400-ed7aa358.pt
# Base key for image 285: 0b228400-ed7aa358
# Saving .pt file: trainA_testing3/0b228400-f829aaa5.pt
# Base key for image 286: 0b228400-f829aaa5
# Saving .pt file: trainA_testing3/0b247132-1efffe84.pt
# Base key for image 287: 0b247132-1efffe84
# Saving .pt file: trainA_testing3/0b247132-ca64ae4c.pt
# Base key for image 288: 0b247132-ca64ae4c
# Saving .pt file: trainA_testing3/0b248335-3f147d5d.pt
# Base key for image 289: 0b248335-3f147d5d
# Saving .pt file: trainA_testing3/0b248335-afe33bec.pt
# Base key for image 290: 0b248335-afe33bec
# Saving .pt file: trainA_testing3/0b351bc5-c895ae48.pt
# Base key for image 291: 0b351bc5-c895ae48
# Saving .pt file: trainA_testing3/0b35752b-1ebd3944.pt
# Base key for image 292: 0b35752b-1ebd3944
# Saving .pt file: trainA_testing3/0b35752b-78beb531.pt
# Base key for image 293: 0b35752b-78beb531
# Saving .pt file: trainA_testing3/0b36ee90-92344015.pt
# Base key for image 294: 0b36ee90-92344015
# Saving .pt file: trainA_testing3/0b36ee90-f89cd13d.pt
# Base key for image 295: 0b36ee90-f89cd13d
# Saving .pt file: trainA_testing3/0b36fdad-f5c619e4.pt
# Base key for image 296: 0b36fdad-f5c619e4
# Saving .pt file: trainA_testing3/0b373e79-acbe5847.pt
# Base key for image 297: 0b373e79-acbe5847
# Saving .pt file: trainA_testing3/0b37664c-65995ce8.pt
# Base key for image 298: 0b37664c-65995ce8
# Saving .pt file: trainA_testing3/0b396e6f-06f3ce96.pt
# Base key for image 299: 0b396e6f-06f3ce96
# Saving .pt file: trainA_testing3/0b396e6f-21948f27.pt
# Base key for image 300: 0b396e6f-21948f27
# Saving .pt file: trainA_testing3/0b396e6f-947d0891.pt
# Base key for image 301: 0b396e6f-947d0891
# Saving .pt file: trainA_testing3/0b396e6f-e75b8338.pt
# Base key for image 302: 0b396e6f-e75b8338
# Saving .pt file: trainA_testing3/0b39b2ea-ef540472.pt
# Base key for image 303: 0b39b2ea-ef540472
# Saving .pt file: trainA_testing3/0b3cbe42-50766e2e.pt
# Base key for image 304: 0b3cbe42-50766e2e
# Saving .pt file: trainA_testing3/0b3d2eb9-39a83a6c.pt
# Base key for image 305: 0b3d2eb9-39a83a6c
# Saving .pt file: trainA_testing3/0b3d47ed-6cb90089.pt
# Base key for image 306: 0b3d47ed-6cb90089
# Saving .pt file: trainA_testing3/0b3e7452-dd888d66.pt
# Base key for image 307: 0b3e7452-dd888d66
# Saving .pt file: trainA_testing3/0b3fa537-f27cf439.pt
# Base key for image 308: 0b3fa537-f27cf439
# Saving .pt file: trainA_testing3/0b4225f9-75ca43b8.pt
# Base key for image 309: 0b4225f9-75ca43b8
# Saving .pt file: trainA_testing3/0b4225f9-bfb10f88.pt
# Base key for image 310: 0b4225f9-bfb10f88
# Saving .pt file: trainA_testing3/0b4225f9-d29472b4.pt
# Base key for image 311: 0b4225f9-d29472b4
# Saving .pt file: trainA_testing3/0b464c35-6a68c0c9.pt
# Base key for image 312: 0b464c35-6a68c0c9
# Saving .pt file: trainA_testing3/0b4892bd-444faa63.pt
# Base key for image 313: 0b4892bd-444faa63
# Saving .pt file: trainA_testing3/0b498ab4-104c3f92.pt
# Base key for image 314: 0b498ab4-104c3f92
# Saving .pt file: trainA_testing3/0b498ab4-61a88e2e.pt
# Base key for image 315: 0b498ab4-61a88e2e
# Saving .pt file: trainA_testing3/0b498ab4-72282bc2.pt
# Base key for image 316: 0b498ab4-72282bc2
# Saving .pt file: trainA_testing3/0b4b161a-ac3c2201.pt
# Base key for image 317: 0b4b161a-ac3c2201
# Saving .pt file: trainA_testing3/0b4c8138-84032f91.pt
# Base key for image 318: 0b4c8138-84032f91
# Saving .pt file: trainA_testing3/0b4c8138-a1953ae5.pt
# Base key for image 319: 0b4c8138-a1953ae5
# Saving .pt file: trainA_testing3/0b4c8138-adfdfb43.pt
# Base key for image 320: 0b4c8138-adfdfb43
# Saving .pt file: trainA_testing3/0b4f2e43-10a52b3e.pt
# Base key for image 321: 0b4f2e43-10a52b3e
# Saving .pt file: trainA_testing3/0b4f2e43-55d1f046.pt
# Base key for image 322: 0b4f2e43-55d1f046
# Saving .pt file: trainA_testing3/0b4f2e43-b0341387.pt
# Base key for image 323: 0b4f2e43-b0341387
# Saving .pt file: trainA_testing3/0b5216a3-4bbd7d22.pt
# Base key for image 324: 0b5216a3-4bbd7d22
# Saving .pt file: trainA_testing3/0b5304e7-4fe66317.pt
# Base key for image 325: 0b5304e7-4fe66317
# Saving .pt file: trainA_testing3/0b53476e-3559f162.pt
# Base key for image 326: 0b53476e-3559f162
# Saving .pt file: trainA_testing3/0b53476e-9d258f61.pt
# Base key for image 327: 0b53476e-9d258f61
# Saving .pt file: trainA_testing3/0b53fd92-22288ae0.pt
# Base key for image 328: 0b53fd92-22288ae0
# Saving .pt file: trainA_testing3/0b5b81ee-ef0e938d.pt
# Base key for image 329: 0b5b81ee-ef0e938d
# Saving .pt file: trainA_testing3/0b5c2365-35b41936.pt
# Base key for image 330: 0b5c2365-35b41936
# Saving .pt file: trainA_testing3/0b607c1a-4eea95b4.pt
# Base key for image 331: 0b607c1a-4eea95b4
# Saving .pt file: trainA_testing3/0b607c1a-e6aaa838.pt
# Base key for image 332: 0b607c1a-e6aaa838
# Saving .pt file: trainA_testing3/0b630871-f0d16c26.pt
# Base key for image 333: 0b630871-f0d16c26
# Saving .pt file: trainA_testing3/0b63c42f-9a2411df.pt
# Base key for image 334: 0b63c42f-9a2411df
# Saving .pt file: trainA_testing3/0b6474d1-36cafb5a.pt
# Base key for image 335: 0b6474d1-36cafb5a
# Saving .pt file: trainA_testing3/0b661d3b-10768db7.pt
# Base key for image 336: 0b661d3b-10768db7
# Saving .pt file: trainA_testing3/0b661d3b-153c8829.pt
# Base key for image 337: 0b661d3b-153c8829
# Saving .pt file: trainA_testing3/0b661d3b-56cec8f5.pt
# Base key for image 338: 0b661d3b-56cec8f5
# Saving .pt file: trainA_testing3/0b661d3b-bbef53a8.pt
# Base key for image 339: 0b661d3b-bbef53a8
# Saving .pt file: trainA_testing3/0b669851-014ff916.pt
# Base key for image 340: 0b669851-014ff916
# Saving .pt file: trainA_testing3/0b669851-11a95d4f.pt
# Base key for image 341: 0b669851-11a95d4f
# Saving .pt file: trainA_testing3/0b669851-2eee54ee.pt
# Base key for image 342: 0b669851-2eee54ee
# Saving .pt file: trainA_testing3/0b669851-c6571777.pt
# Base key for image 343: 0b669851-c6571777
# Saving .pt file: trainA_testing3/0b6781f6-eeb5fc5f.pt
# Base key for image 344: 0b6781f6-eeb5fc5f
# Saving .pt file: trainA_testing3/0b678b38-4a44d5fe.pt
# Base key for image 345: 0b678b38-4a44d5fe
# Saving .pt file: trainA_testing3/0b68157c-9780d718.pt
# Base key for image 346: 0b68157c-9780d718
# Saving .pt file: trainA_testing3/0b68e992-ac6161ca.pt
# Base key for image 347: 0b68e992-ac6161ca
# Saving .pt file: trainA_testing3/0b6c3c8a-c5c55632.pt
# Base key for image 348: 0b6c3c8a-c5c55632
# Saving .pt file: trainA_testing3/0b6d7f5b-d1fa6fe5.pt
# Base key for image 349: 0b6d7f5b-d1fa6fe5
# Saving .pt file: trainA_testing3/0b6dd7d8-ff3ac76b.pt
# Base key for image 350: 0b6dd7d8-ff3ac76b
# Saving .pt file: trainA_testing3/0b726a43-ae3ee8e9.pt
# Base key for image 351: 0b726a43-ae3ee8e9
# Saving .pt file: trainA_testing3/0b744ab1-f8e01c96.pt
# Base key for image 352: 0b744ab1-f8e01c96
# Saving .pt file: trainA_testing3/0b744ae5-176e0cce.pt
# Base key for image 353: 0b744ae5-176e0cce
# Saving .pt file: trainA_testing3/0b744ae5-7a012c3c.pt
# Base key for image 354: 0b744ae5-7a012c3c
# Saving .pt file: trainA_testing3/0b76dd7e-96db9654.pt
# Base key for image 355: 0b76dd7e-96db9654
# Saving .pt file: trainA_testing3/0b76dd7e-a198f275.pt
# Base key for image 356: 0b76dd7e-a198f275
# Saving .pt file: trainA_testing3/0b796e55-0d102bd0.pt
# Base key for image 357: 0b796e55-0d102bd0
# Saving .pt file: trainA_testing3/0b7cbaa7-6a650606.pt
# Base key for image 358: 0b7cbaa7-6a650606
# Saving .pt file: trainA_testing3/0b7cbaa7-d677bc73.pt
# Base key for image 359: 0b7cbaa7-d677bc73
# Saving .pt file: trainA_testing3/0b7ed7b9-7cf25a7b.pt
# Base key for image 360: 0b7ed7b9-7cf25a7b
# Saving .pt file: trainA_testing3/0b80f475-55a8484e.pt
# Base key for image 361: 0b80f475-55a8484e
# Saving .pt file: trainA_testing3/0b833acc-d74ec101.pt
# Base key for image 362: 0b833acc-d74ec101
# Saving .pt file: trainA_testing3/0b84641a-2c1532fd.pt
# Base key for image 363: 0b84641a-2c1532fd
# Saving .pt file: trainA_testing3/0b84641a-c360bebd.pt
# Base key for image 364: 0b84641a-c360bebd
# Saving .pt file: trainA_testing3/0b84641a-cbca8d62.pt
# Base key for image 365: 0b84641a-cbca8d62
# Saving .pt file: trainA_testing3/0b8896f8-912fdafb.pt
# Base key for image 366: 0b8896f8-912fdafb
# Saving .pt file: trainA_testing3/0b8aaad8-90bba881.pt
# Base key for image 367: 0b8aaad8-90bba881
# Saving .pt file: trainA_testing3/0b8b0111-01aac1a5.pt
# Base key for image 368: 0b8b0111-01aac1a5
# Saving .pt file: trainA_testing3/0b8b0111-3e546d48.pt
# Base key for image 369: 0b8b0111-3e546d48
# Saving .pt file: trainA_testing3/0b8b0111-a5a06f63.pt
# Base key for image 370: 0b8b0111-a5a06f63
# Saving .pt file: trainA_testing3/0b8fa979-363926f5.pt
# Base key for image 371: 0b8fa979-363926f5
# Saving .pt file: trainA_testing3/0b90f293-089b918a.pt
# Base key for image 372: 0b90f293-089b918a
# Saving .pt file: trainA_testing3/0b911639-98f93d75.pt
# Base key for image 373: 0b911639-98f93d75
# Saving .pt file: trainA_testing3/0b95721d-fb1789c4.pt
# Base key for image 374: 0b95721d-fb1789c4
# Saving .pt file: trainA_testing3/0b9770dc-744899a4.pt
# Base key for image 375: 0b9770dc-744899a4
# Saving .pt file: trainA_testing3/0b99a8e1-42e1d010.pt
# Base key for image 376: 0b99a8e1-42e1d010
# Saving .pt file: trainA_testing3/0b9c0b53-5141b893.pt
# Base key for image 377: 0b9c0b53-5141b893
# Saving .pt file: trainA_testing3/0b9c4f05-d59b8eec.pt
# Base key for image 378: 0b9c4f05-d59b8eec
# Saving .pt file: trainA_testing3/0b9c97f8-32c33f08.pt
# Base key for image 379: 0b9c97f8-32c33f08
# Saving .pt file: trainA_testing3/0b9cf19a-8e02c78d.pt
# Base key for image 380: 0b9cf19a-8e02c78d
# Saving .pt file: trainA_testing3/0b9e72e1-2855d45f.pt
# Base key for image 381: 0b9e72e1-2855d45f
# Saving .pt file: trainA_testing3/0b9e72e1-ac813d70.pt
# Base key for image 382: 0b9e72e1-ac813d70
# Saving .pt file: trainA_testing3/0b9ecf40-0cc71bee.pt
# Base key for image 383: 0b9ecf40-0cc71bee
# Saving .pt file: trainA_testing3/0b9fa855-09cc8f5a.pt
# Base key for image 384: 0b9fa855-09cc8f5a
# Saving .pt file: trainA_testing3/0b9fa855-936aae7a.pt
# Base key for image 385: 0b9fa855-936aae7a
# Saving .pt file: trainA_testing3/0ba01bd3-19727e8b.pt
# Base key for image 386: 0ba01bd3-19727e8b
# Saving .pt file: trainA_testing3/0ba01bd3-afb758f2.pt
# Base key for image 387: 0ba01bd3-afb758f2
# Saving .pt file: trainA_testing3/0ba01bd3-c31fe7ae.pt
# Base key for image 388: 0ba01bd3-c31fe7ae
# Saving .pt file: trainA_testing3/0bb074f1-3da7bf3f.pt
# Base key for image 389: 0bb074f1-3da7bf3f
# Saving .pt file: trainA_testing3/0bc0b27e-d46482f4.pt
# Base key for image 390: 0bc0b27e-d46482f4
# Saving .pt file: trainA_testing3/0bc0b27e-e18eb6d7.pt
# Base key for image 391: 0bc0b27e-e18eb6d7
# Saving .pt file: trainA_testing3/0bc195d8-625d8d27.pt
# Base key for image 392: 0bc195d8-625d8d27
# Saving .pt file: trainA_testing3/0bc195d8-b13d1ec3.pt
# Base key for image 393: 0bc195d8-b13d1ec3
# Saving .pt file: trainA_testing3/0bc66c92-5cfb80fc.pt
# Base key for image 394: 0bc66c92-5cfb80fc
# Saving .pt file: trainA_testing3/0bc66c92-dfef0a1e.pt
# Base key for image 395: 0bc66c92-dfef0a1e
# Saving .pt file: trainA_testing3/0bc866ed-1abb6bcd.pt
# Base key for image 396: 0bc866ed-1abb6bcd
# Saving .pt file: trainA_testing3/0bc866ed-65b95343.pt
# Base key for image 397: 0bc866ed-65b95343
# Saving .pt file: trainA_testing3/0bca5622-81fd1686.pt
# Base key for image 398: 0bca5622-81fd1686
# Saving .pt file: trainA_testing3/0bca5622-b2be4f9a.pt
# Base key for image 399: 0bca5622-b2be4f9a
# Saving .pt file: trainA_testing3/0bca9932-facfb675.pt
# Base key for image 400: 0bca9932-facfb675
# Saving .pt file: trainA_testing3/0bcc752f-969d23ca.pt
# Base key for image 401: 0bcc752f-969d23ca
# Saving .pt file: trainA_testing3/0bcc752f-99a6b169.pt
# Base key for image 402: 0bcc752f-99a6b169
# Saving .pt file: trainA_testing3/0bcc752f-fd302777.pt
# Base key for image 403: 0bcc752f-fd302777
# Saving .pt file: trainA_testing3/0bcdf85e-8b497ade.pt
# Base key for image 404: 0bcdf85e-8b497ade
# Saving .pt file: trainA_testing3/0bce68c1-629ddf0d.pt
# Base key for image 405: 0bce68c1-629ddf0d
# Saving .pt file: trainA_testing3/0bd0515d-8ade9b32.pt
# Base key for image 406: 0bd0515d-8ade9b32
# Saving .pt file: trainA_testing3/0bd4fbef-673efc2d.pt
# Base key for image 407: 0bd4fbef-673efc2d
# Saving .pt file: trainA_testing3/0bd785cc-8770b059.pt
# Base key for image 408: 0bd785cc-8770b059
# Saving .pt file: trainA_testing3/0bd785cc-de69b433.pt
# Base key for image 409: 0bd785cc-de69b433
# Saving .pt file: trainA_testing3/0bd87fe6-11126e07.pt
# Base key for image 410: 0bd87fe6-11126e07
# Saving .pt file: trainA_testing3/0bda8935-8846048a.pt
# Base key for image 411: 0bda8935-8846048a
# Saving .pt file: trainA_testing3/0bdce5bc-48014892.pt
# Base key for image 412: 0bdce5bc-48014892
# Saving .pt file: trainA_testing3/0bdce5bc-5657a024.pt
# Base key for image 413: 0bdce5bc-5657a024
# Saving .pt file: trainA_testing3/0bdce5bc-ed2d1636.pt
# Base key for image 414: 0bdce5bc-ed2d1636
# Saving .pt file: trainA_testing3/0bdf03ce-38a61980.pt
# Base key for image 415: 0bdf03ce-38a61980
# Saving .pt file: trainA_testing3/0bdf03ce-9c7c3492.pt
# Base key for image 416: 0bdf03ce-9c7c3492
# Saving .pt file: trainA_testing3/0bdf93e9-02db60c4.pt
# Base key for image 417: 0bdf93e9-02db60c4
# Saving .pt file: trainA_testing3/0be031c3-32a8ed04.pt
# Base key for image 418: 0be031c3-32a8ed04
# Saving .pt file: trainA_testing3/0be031c3-59881f07.pt
# Base key for image 419: 0be031c3-59881f07
# Saving .pt file: trainA_testing3/0be031c3-81b6e5b7.pt
# Base key for image 420: 0be031c3-81b6e5b7
# Saving .pt file: trainA_testing3/0be14aff-6ca54251.pt
# Base key for image 421: 0be14aff-6ca54251
# Saving .pt file: trainA_testing3/0be36567-b625af7f.pt
# Base key for image 422: 0be36567-b625af7f
# Saving .pt file: trainA_testing3/0be36567-bee11e9c.pt
# Base key for image 423: 0be36567-bee11e9c
# Saving .pt file: trainA_testing3/0be3a23f-e329a79b.pt
# Base key for image 424: 0be3a23f-e329a79b
# Saving .pt file: trainA_testing3/0be3da2f-16e6918b.pt
# Base key for image 425: 0be3da2f-16e6918b
# Saving .pt file: trainA_testing3/0be60f15-4bd4b9d4.pt
# Base key for image 426: 0be60f15-4bd4b9d4
# Saving .pt file: trainA_testing3/0be6646a-763ab32d.pt
# Base key for image 427: 0be6646a-763ab32d
# Saving .pt file: trainA_testing3/0be7370c-f90dfe91.pt
# Base key for image 428: 0be7370c-f90dfe91
# Saving .pt file: trainA_testing3/0beab4e0-60a208eb.pt
# Base key for image 429: 0beab4e0-60a208eb
# Saving .pt file: trainA_testing3/0bed85e1-72950ce8.pt
# Base key for image 430: 0bed85e1-72950ce8
# Saving .pt file: trainA_testing3/0bed85e1-cfaa2455.pt
# Base key for image 431: 0bed85e1-cfaa2455
# Saving .pt file: trainA_testing3/0bed85e1-d6eca0a1.pt
# Base key for image 432: 0bed85e1-d6eca0a1
# Saving .pt file: trainA_testing3/0beff145-93a9ceeb.pt
# Base key for image 433: 0beff145-93a9ceeb
# Saving .pt file: trainA_testing3/0bf1c902-0b549723.pt
# Base key for image 434: 0bf1c902-0b549723
# Saving .pt file: trainA_testing3/0bf1c902-7a1778df.pt
# Base key for image 435: 0bf1c902-7a1778df
# Saving .pt file: trainA_testing3/0bf1c902-98c04a78.pt
# Base key for image 436: 0bf1c902-98c04a78
# Saving .pt file: trainA_testing3/0bf1c902-d84fa0fa.pt
# Base key for image 437: 0bf1c902-d84fa0fa
# Saving .pt file: trainA_testing3/0bf1c902-ee543be5.pt
# Base key for image 438: 0bf1c902-ee543be5
# Saving .pt file: trainA_testing3/0bf28365-020515e2.pt
# Base key for image 439: 0bf28365-020515e2
# Saving .pt file: trainA_testing3/0bf28365-8e62e245.pt
# Base key for image 440: 0bf28365-8e62e245
# Saving .pt file: trainA_testing3/0bf2ff3e-19bb5f59.pt
# Base key for image 441: 0bf2ff3e-19bb5f59
# Saving .pt file: trainA_testing3/0bf2ff3e-58c39471.pt
# Base key for image 442: 0bf2ff3e-58c39471
# Saving .pt file: trainA_testing3/0bf2ff3e-6ee7f304.pt
# Base key for image 443: 0bf2ff3e-6ee7f304
# Saving .pt file: trainA_testing3/0bf3773d-1563c3e1.pt
# Base key for image 444: 0bf3773d-1563c3e1
# Saving .pt file: trainA_testing3/0bf4162f-ab9fe384.pt
# Base key for image 445: 0bf4162f-ab9fe384
# Saving .pt file: trainA_testing3/0bf6d230-656be21a.pt
# Base key for image 446: 0bf6d230-656be21a
# Saving .pt file: trainA_testing3/0bf8851e-aab7837b.pt
# Base key for image 447: 0bf8851e-aab7837b
# Saving .pt file: trainA_testing3/0bf8851e-c43ef9d2.pt
# Base key for image 448: 0bf8851e-c43ef9d2
# Saving .pt file: trainA_testing3/0bf8851e-e3f5b31d.pt
# Base key for image 449: 0bf8851e-e3f5b31d
# Saving .pt file: trainA_testing3/0bf91dc7-620f4b74.pt
# Base key for image 450: 0bf91dc7-620f4b74
# Saving .pt file: trainA_testing3/0bff2099-638f8f79.pt
# Base key for image 451: 0bff2099-638f8f79
# Saving .pt file: trainA_testing3/0bff2099-f45eb90d.pt
# Base key for image 452: 0bff2099-f45eb90d
# Saving .pt file: trainA_testing3/0c000570-56379e8e.pt
# Base key for image 453: 0c000570-56379e8e
# Saving .pt file: trainA_testing3/0c005860-45e2b557.pt
# Base key for image 454: 0c005860-45e2b557
# Saving .pt file: trainA_testing3/0c005860-df3ef7d3.pt
# Base key for image 455: 0c005860-df3ef7d3
# Saving .pt file: trainA_testing3/0c044a1d-3713f14f.pt
# Base key for image 456: 0c044a1d-3713f14f
# Saving .pt file: trainA_testing3/0c04d29a-6bf85baf.pt
# Base key for image 457: 0c04d29a-6bf85baf
# Saving .pt file: trainA_testing3/0c07cd68-46b1d5db.pt
# Base key for image 458: 0c07cd68-46b1d5db
# Saving .pt file: trainA_testing3/0c0a0364-a6a4a979.pt
# Base key for image 459: 0c0a0364-a6a4a979
# Saving .pt file: trainA_testing3/0c0eb90b-fade0f1e.pt
# Base key for image 460: 0c0eb90b-fade0f1e
# Saving .pt file: trainA_testing3/0c0f1e4f-5e763399.pt
# Base key for image 461: 0c0f1e4f-5e763399
# Saving .pt file: trainA_testing3/0c0f3d8e-01cf0018.pt
# Base key for image 462: 0c0f3d8e-01cf0018
# Saving .pt file: trainA_testing3/0c0f3d8e-44d6a26d.pt
# Base key for image 463: 0c0f3d8e-44d6a26d
# Saving .pt file: trainA_testing3/0c0f3d8e-6bc3e50c.pt
# Base key for image 464: 0c0f3d8e-6bc3e50c
# Saving .pt file: trainA_testing3/0c0f3d8e-a0b45852.pt
# Base key for image 465: 0c0f3d8e-a0b45852
# Saving .pt file: trainA_testing3/0c11a340-6a71bfcf.pt
# Base key for image 466: 0c11a340-6a71bfcf
# Saving .pt file: trainA_testing3/0c13b339-aa4c659e.pt
# Base key for image 467: 0c13b339-aa4c659e
# Saving .pt file: trainA_testing3/0c13b339-fac6ef24.pt
# Base key for image 468: 0c13b339-fac6ef24
# Saving .pt file: trainA_testing3/0c140522-190b25a3.pt
# Base key for image 469: 0c140522-190b25a3
# Saving .pt file: trainA_testing3/0c140522-227e6f11.pt
# Base key for image 470: 0c140522-227e6f11
# Saving .pt file: trainA_testing3/0c140522-57d3aac5.pt
# Base key for image 471: 0c140522-57d3aac5
# Saving .pt file: trainA_testing3/0c140522-681c508d.pt
# Base key for image 472: 0c140522-681c508d
# Saving .pt file: trainA_testing3/0c154337-09dd2a21.pt
# Base key for image 473: 0c154337-09dd2a21
# Saving .pt file: trainA_testing3/0c1e95b5-d08ee38f.pt
# Base key for image 474: 0c1e95b5-d08ee38f
# Saving .pt file: trainA_testing3/0c28dcae-7f85d6a4.pt
# Base key for image 475: 0c28dcae-7f85d6a4
# Saving .pt file: trainA_testing3/0c28dcae-c3c1e002.pt
# Base key for image 476: 0c28dcae-c3c1e002
# Saving .pt file: trainA_testing3/0c28e5a2-5348be35.pt
# Base key for image 477: 0c28e5a2-5348be35
# Saving .pt file: trainA_testing3/0c297417-393473aa.pt
# Base key for image 478: 0c297417-393473aa
# Saving .pt file: trainA_testing3/0c2a5664-72e9c581.pt
# Base key for image 479: 0c2a5664-72e9c581
# Saving .pt file: trainA_testing3/0c2c1dd4-6233f932.pt
# Base key for image 480: 0c2c1dd4-6233f932
# Saving .pt file: trainA_testing3/0c2cb3d5-0bdfc2f9.pt
# Base key for image 481: 0c2cb3d5-0bdfc2f9
# Saving .pt file: trainA_testing3/0c2f0e6d-c9334af1.pt
# Base key for image 482: 0c2f0e6d-c9334af1
# Saving .pt file: trainA_testing3/0c2f230d-b520ff53.pt
# Base key for image 483: 0c2f230d-b520ff53
# Saving .pt file: trainA_testing3/0c2f33b9-8361f99f.pt
# Base key for image 484: 0c2f33b9-8361f99f
# Saving .pt file: trainA_testing3/0c2f33b9-f94d69b5.pt
# Base key for image 485: 0c2f33b9-f94d69b5
# Saving .pt file: trainA_testing3/0c30d205-1fcf5de3.pt
# Base key for image 486: 0c30d205-1fcf5de3
# Saving .pt file: trainA_testing3/0c30d205-e7934ed3.pt
# Base key for image 487: 0c30d205-e7934ed3
# Saving .pt file: trainA_testing3/0c32a627-c812f5fe.pt
# Base key for image 488: 0c32a627-c812f5fe
# Saving .pt file: trainA_testing3/0c3407af-25f7b68a.pt
# Base key for image 489: 0c3407af-25f7b68a
# Saving .pt file: trainA_testing3/0c34273d-87a7edaa.pt
# Base key for image 490: 0c34273d-87a7edaa
# Saving .pt file: trainA_testing3/0c34273d-9d0fff7b.pt
# Base key for image 491: 0c34273d-9d0fff7b
# Saving .pt file: trainA_testing3/0c370eb5-c45031e2.pt
# Base key for image 492: 0c370eb5-c45031e2
# Saving .pt file: trainA_testing3/0c378f4f-e2ddeffe.pt
# Base key for image 493: 0c378f4f-e2ddeffe
# Saving .pt file: trainA_testing3/0c37f221-03d9ad48.pt
# Base key for image 494: 0c37f221-03d9ad48
# Saving .pt file: trainA_testing3/0c37f221-0b34c3cd.pt
# Base key for image 495: 0c37f221-0b34c3cd
# Saving .pt file: trainA_testing3/0c37f221-1b5da330.pt
# Base key for image 496: 0c37f221-1b5da330
# Saving .pt file: trainA_testing3/0c37f221-7fffa860.pt
# Base key for image 497: 0c37f221-7fffa860
# Saving .pt file: trainA_testing3/0c37f221-e2897443.pt
# Base key for image 498: 0c37f221-e2897443
# Saving .pt file: trainA_testing3/0c37f221-f8157003.pt
# Base key for image 499: 0c37f221-f8157003
# Saving .pt file: trainA_testing3/0c3bef37-6b979c98.pt
# Base key for image 500: 0c3bef37-6b979c98
# ...
# Base key for image 533: 0c5faf8b-0aa02f50
# Saving .pt file: trainA_testing3/0c5faf8b-aeceb406.pt
# Base key for image 534: 0c5faf8b-aeceb406
# Saving .pt file: trainA_testing3/0c5ff0c6-b1853637.pt
# Base key for image 535: 0c5ff0c6-b1853637
# Saving .pt file: trainA_testing3/0c5ff0c6-d547ace3.pt
# Base key for image 536: 0c5ff0c6-d547ace3
# Saving .pt file: trainA_testing3/0c60d6e3-57bc4ba0.pt
# Base key for image 537: 0c60d6e3-57bc4ba0
# Saving .pt file: trainA_testing3/0c639b9e-288920be.pt
# Base key for image 538: 0c639b9e-288920be
# Saving .pt file: trainA_testing3/0c639b9e-2f447867.pt
# Base key for image 539: 0c639b9e-2f447867
# Saving .pt file: trainA_testing3/0c639b9e-44e4bc1e.pt
# Base key for image 540: 0c639b9e-44e4bc1e
# Saving .pt file: trainA_testing3/0c639b9e-69d332a8.pt
# Base key for image 541: 0c639b9e-69d332a8
# Saving .pt file: trainA_testing3/0c665e73-cd1db64b.pt
# Base key for image 542: 0c665e73-cd1db64b
# Saving .pt file: trainA_testing3/0c66b959-1547776b.pt
# Base key for image 543: 0c66b959-1547776b
# Saving .pt file: trainA_testing3/0c688c93-5f0c8068.pt
# Base key for image 544: 0c688c93-5f0c8068
# Saving .pt file: trainA_testing3/0c6c4570-5e0537e5.pt
# Base key for image 545: 0c6c4570-5e0537e5
# Saving .pt file: trainA_testing3/0c6c4570-ef7a1e81.pt
# Base key for image 546: 0c6c4570-ef7a1e81
# Saving .pt file: trainA_testing3/0c6c9c66-5e86e200.pt
# Base key for image 547: 0c6c9c66-5e86e200
# Saving .pt file: trainA_testing3/0c6d870a-f2991621.pt
# Base key for image 548: 0c6d870a-f2991621
# Saving .pt file: trainA_testing3/0c723372-b5a2dcdb.pt
# Base key for image 549: 0c723372-b5a2dcdb
# Saving .pt file: trainA_testing3/0c723f1a-ac40d060.pt
# Base key for image 550: 0c723f1a-ac40d060
# Saving .pt file: trainA_testing3/0c723f1a-fb4537fd.pt
# Base key for image 551: 0c723f1a-fb4537fd
# Saving .pt file: trainA_testing3/0c738361-677fa50d.pt
# Base key for image 552: 0c738361-677fa50d
# Saving .pt file: trainA_testing3/0c774f7d-a8305951.pt
# Base key for image 553: 0c774f7d-a8305951
# Saving .pt file: trainA_testing3/0c774f7d-ba854ba6.pt
# Base key for image 554: 0c774f7d-ba854ba6
# Saving .pt file: trainA_testing3/0c775a1a-4f7ad1e4.pt
# Base key for image 555: 0c775a1a-4f7ad1e4
# Saving .pt file: trainA_testing3/0c791f05-2275d44e.pt
# Base key for image 556: 0c791f05-2275d44e
# Saving .pt file: trainA_testing3/0c7b1a08-308fabfa.pt
# Base key for image 557: 0c7b1a08-308fabfa
# Saving .pt file: trainA_testing3/0c7ccf61-75482780.pt
# Base key for image 558: 0c7ccf61-75482780
# Saving .pt file: trainA_testing3/0c81ee49-93738b9d.pt
# Base key for image 559: 0c81ee49-93738b9d
# Saving .pt file: trainA_testing3/0c85ac7b-ba0cc91c.pt
# Base key for image 560: 0c85ac7b-ba0cc91c
# Saving .pt file: trainA_testing3/0c86d1c5-2e0db5be.pt
# Base key for image 561: 0c86d1c5-2e0db5be
# Saving .pt file: trainA_testing3/0c86d1c5-5daba15f.pt
# Base key for image 562: 0c86d1c5-5daba15f
# Saving .pt file: trainA_testing3/0c8a2c79-9e9ef9ab.pt
# Base key for image 563: 0c8a2c79-9e9ef9ab
# Saving .pt file: trainA_testing3/0c8b32af-2d9a2bad.pt
# Base key for image 564: 0c8b32af-2d9a2bad
# Saving .pt file: trainA_testing3/0c8cbbf9-c3bde0a5.pt
# Base key for image 565: 0c8cbbf9-c3bde0a5
# Saving .pt file: trainA_testing3/0c8d4258-6f9554c0.pt
# Base key for image 566: 0c8d4258-6f9554c0
# Saving .pt file: trainA_testing3/0c8d884d-33f0e078.pt
# Base key for image 567: 0c8d884d-33f0e078
# Saving .pt file: trainA_testing3/0c8e4f10-b7727d75.pt
# Base key for image 568: 0c8e4f10-b7727d75
# Saving .pt file: trainA_testing3/0c91c363-9e274ad1.pt
# Base key for image 569: 0c91c363-9e274ad1
# Saving .pt file: trainA_testing3/0c947849-1dbd3021.pt
# Base key for image 570: 0c947849-1dbd3021
# Saving .pt file: trainA_testing3/0c96e121-43cf26ef.pt
# Base key for image 571: 0c96e121-43cf26ef
# Saving .pt file: trainA_testing3/0c96e121-5630b866.pt
# Base key for image 572: 0c96e121-5630b866
# Saving .pt file: trainA_testing3/0c96e121-6be3ef9b.pt
# Base key for image 573: 0c96e121-6be3ef9b
# Saving .pt file: trainA_testing3/0c96e121-8398710b.pt
# Base key for image 574: 0c96e121-8398710b
# Saving .pt file: trainA_testing3/0c9709c1-7f5e9b16.pt
# Base key for image 575: 0c9709c1-7f5e9b16
# Saving .pt file: trainA_testing3/0c9722f4-a43f5894.pt
# Base key for image 576: 0c9722f4-a43f5894
# Saving .pt file: trainA_testing3/0c984e6d-2b5d7ee4.pt
# Base key for image 577: 0c984e6d-2b5d7ee4
# Saving .pt file: trainA_testing3/0c9a1af8-dd3b8b7c.pt
# Base key for image 578: 0c9a1af8-dd3b8b7c
# Saving .pt file: trainA_testing3/0c9f5bb9-459661f6.pt
# Base key for image 579: 0c9f5bb9-459661f6
# Saving .pt file: trainA_testing3/0c9f5bb9-4d89a4ed.pt
# Base key for image 580: 0c9f5bb9-4d89a4ed
# Saving .pt file: trainA_testing3/0c9fa4c0-89de5b85.pt
# Base key for image 581: 0c9fa4c0-89de5b85
# Saving .pt file: trainA_testing3/0ca4489b-eb80b57d.pt
# Base key for image 582: 0ca4489b-eb80b57d
# Saving .pt file: trainA_testing3/0ca4bf18-1861b4c7.pt
# Base key for image 583: 0ca4bf18-1861b4c7
# Saving .pt file: trainA_testing3/0ca4bf18-be5ee8c4.pt
# Base key for image 584: 0ca4bf18-be5ee8c4
# Saving .pt file: trainA_testing3/0ca51d19-f2fe7c31.pt
# Base key for image 585: 0ca51d19-f2fe7c31
# Saving .pt file: trainA_testing3/0ca74451-808a5064.pt
# Base key for image 586: 0ca74451-808a5064
# Saving .pt file: trainA_testing3/0ca79ef3-364ea94f.pt
# Base key for image 587: 0ca79ef3-364ea94f
# Saving .pt file: trainA_testing3/0ca79ef3-eabeec85.pt
# Base key for image 588: 0ca79ef3-eabeec85
# Saving .pt file: trainA_testing3/0ca7d4fe-303c9d8a.pt
# Base key for image 589: 0ca7d4fe-303c9d8a
# Saving .pt file: trainA_testing3/0ca7d4fe-362c775d.pt
# Base key for image 590: 0ca7d4fe-362c775d
# Saving .pt file: trainA_testing3/0ca7d4fe-7eaf5269.pt
# Base key for image 591: 0ca7d4fe-7eaf5269
# Saving .pt file: trainA_testing3/0ca7d4fe-b9fc533d.pt
# Base key for image 592: 0ca7d4fe-b9fc533d
# Saving .pt file: trainA_testing3/0ca8aa90-320f3a64.pt
# Base key for image 593: 0ca8aa90-320f3a64
# Saving .pt file: trainA_testing3/0ca8aa90-615caa0c.pt
# Base key for image 594: 0ca8aa90-615caa0c
# Saving .pt file: trainA_testing3/0ca8d9fa-0aadd2ca.pt
# Base key for image 595: 0ca8d9fa-0aadd2ca
# Saving .pt file: trainA_testing3/0caba52c-c1431df9.pt
# Base key for image 596: 0caba52c-c1431df9
# Saving .pt file: trainA_testing3/0cafe7ab-e22edf50.pt
# Base key for image 597: 0cafe7ab-e22edf50
# Saving .pt file: trainA_testing3/0cb47bfe-4ce9e4b2.pt
# Base key for image 598: 0cb47bfe-4ce9e4b2
# Saving .pt file: trainA_testing3/0cb47bfe-691dd68b.pt
# Base key for image 599: 0cb47bfe-691dd68b
# Saving .pt file: trainA_testing3/0cb47bfe-739b26e5.pt
# Base key for image 600: 0cb47bfe-739b26e5
# Saving .pt file: trainA_testing3/0cb47bfe-8980f26e.pt
# Base key for image 601: 0cb47bfe-8980f26e
# Saving .pt file: trainA_testing3/0cb47bfe-9629a8f2.pt
# Base key for image 602: 0cb47bfe-9629a8f2
# Saving .pt file: trainA_testing3/0cb47bfe-f256df88.pt
# Base key for image 603: 0cb47bfe-f256df88
# Saving .pt file: trainA_testing3/0cb67a01-111cb252.pt
# Base key for image 604: 0cb67a01-111cb252
# Saving .pt file: trainA_testing3/0cb67a01-7cf1687e.pt
# Base key for image 605: 0cb67a01-7cf1687e
# Saving .pt file: trainA_testing3/0cb779ad-3a1245a3.pt
# Base key for image 606: 0cb779ad-3a1245a3
# Saving .pt file: trainA_testing3/0cb7fe1d-8bb07eed.pt
# Base key for image 607: 0cb7fe1d-8bb07eed
# Saving .pt file: trainA_testing3/0cb916c7-81e6784a.pt
# Base key for image 608: 0cb916c7-81e6784a
# Saving .pt file: trainA_testing3/0cbb7b3f-fed721c3.pt
# Base key for image 609: 0cbb7b3f-fed721c3
# Saving .pt file: trainA_testing3/0cbc4cff-a698f534.pt
# Base key for image 610: 0cbc4cff-a698f534
# Saving .pt file: trainA_testing3/0cbda188-5dc57888.pt
# Base key for image 611: 0cbda188-5dc57888
# Saving .pt file: trainA_testing3/0cbdd20d-6ce7dfa3.pt
# Base key for image 612: 0cbdd20d-6ce7dfa3
# Saving .pt file: trainA_testing3/0cc0b14d-cd6ab3be.pt
# Base key for image 613: 0cc0b14d-cd6ab3be
# Saving .pt file: trainA_testing3/0cc2eb4e-a1de6079.pt
# Base key for image 614: 0cc2eb4e-a1de6079
# Saving .pt file: trainA_testing3/0cc45408-ce95bf47.pt
# Base key for image 615: 0cc45408-ce95bf47
# Saving .pt file: trainA_testing3/0cc4f47d-59963181.pt
# Base key for image 616: 0cc4f47d-59963181
# Saving .pt file: trainA_testing3/0cc4f47d-78417f6f.pt
# Base key for image 617: 0cc4f47d-78417f6f
# Saving .pt file: trainA_testing3/0cc4f47d-ff0d6e73.pt
# Base key for image 618: 0cc4f47d-ff0d6e73
# Saving .pt file: trainA_testing3/0cc675b1-ebf1b337.pt
# Base key for image 619: 0cc675b1-ebf1b337
# Saving .pt file: trainA_testing3/0cc6dc2e-abf312a7.pt
# Base key for image 620: 0cc6dc2e-abf312a7
# Saving .pt file: trainA_testing3/0cc6f3e8-b4c9e348.pt
# Base key for image 621: 0cc6f3e8-b4c9e348
# Saving .pt file: trainA_testing3/0cc6f7a9-1112b9dc.pt
# Base key for image 622: 0cc6f7a9-1112b9dc
# Saving .pt file: trainA_testing3/0cc6f7a9-209e3736.pt
# Base key for image 623: 0cc6f7a9-209e3736
# Saving .pt file: trainA_testing3/0cc6f7a9-6083566a.pt
# Base key for image 624: 0cc6f7a9-6083566a
# Saving .pt file: trainA_testing3/0cc6f7a9-b6f8d39e.pt
# Base key for image 625: 0cc6f7a9-b6f8d39e
# Saving .pt file: trainA_testing3/0cc8549e-8d3dd4d8.pt
# Base key for image 626: 0cc8549e-8d3dd4d8
# Saving .pt file: trainA_testing3/0cc88ec8-c13edc7e.pt
# Base key for image 627: 0cc88ec8-c13edc7e
# Saving .pt file: trainA_testing3/0cc96b1c-785e141b.pt
# Base key for image 628: 0cc96b1c-785e141b
# Saving .pt file: trainA_testing3/0cca3543-9d44351e.pt
# Base key for image 629: 0cca3543-9d44351e
# Saving .pt file: trainA_testing3/0cca6223-bbe8997f.pt
# Base key for image 630: 0cca6223-bbe8997f
# Saving .pt file: trainA_testing3/0ccc2c51-35e55706.pt
# Base key for image 631: 0ccc2c51-35e55706
# Saving .pt file: trainA_testing3/0ccebe89-e9669633.pt
# Base key for image 632: 0ccebe89-e9669633
# Saving .pt file: trainA_testing3/0cd03801-6a226ab9.pt
# Base key for image 633: 0cd03801-6a226ab9
# Saving .pt file: trainA_testing3/0cd0ba08-c8b0a29d.pt
# Base key for image 634: 0cd0ba08-c8b0a29d
# Saving .pt file: trainA_testing3/0cd440c4-31cf6726.pt
# Base key for image 635: 0cd440c4-31cf6726
# Saving .pt file: trainA_testing3/0cdaa475-100fd615.pt
# Base key for image 636: 0cdaa475-100fd615
# Saving .pt file: trainA_testing3/0cdaa475-135c7ac8.pt
# Base key for image 637: 0cdaa475-135c7ac8
# Saving .pt file: trainA_testing3/0cdaa475-5beaa7b5.pt
# Base key for image 638: 0cdaa475-5beaa7b5
# Saving .pt file: trainA_testing3/0cdc6da9-1febe314.pt
# Base key for image 639: 0cdc6da9-1febe314
# Saving .pt file: trainA_testing3/0cdde16a-e2d9677e.pt
# Base key for image 640: 0cdde16a-e2d9677e
# Saving .pt file: trainA_testing3/0cdde16a-e7a0d875.pt
# Base key for image 641: 0cdde16a-e7a0d875
# Saving .pt file: trainA_testing3/0cdf70ed-39ce9bad.pt
# Base key for image 642: 0cdf70ed-39ce9bad
# Saving .pt file: trainA_testing3/0cdf70ed-ad415e71.pt
# Base key for image 643: 0cdf70ed-ad415e71
# Saving .pt file: trainA_testing3/0ce05c8b-98636a99.pt
# Base key for image 644: 0ce05c8b-98636a99
# Saving .pt file: trainA_testing3/0ce35f68-b55c4229.pt
# Base key for image 645: 0ce35f68-b55c4229
# Saving .pt file: trainA_testing3/0ce3ea39-a5ded49c.pt
# Base key for image 646: 0ce3ea39-a5ded49c
# Saving .pt file: trainA_testing3/0ce5101a-0280b606.pt
# Base key for image 647: 0ce5101a-0280b606
# Saving .pt file: trainA_testing3/0ce5101a-08b03d25.pt
# Base key for image 648: 0ce5101a-08b03d25
# Saving .pt file: trainA_testing3/0ce5101a-36562e6a.pt
# Base key for image 649: 0ce5101a-36562e6a
# Saving .pt file: trainA_testing3/0ce5101a-39704188.pt
# Base key for image 650: 0ce5101a-39704188
# Saving .pt file: trainA_testing3/0ce5101a-9f7e7fd8.pt
# Base key for image 651: 0ce5101a-9f7e7fd8
# Saving .pt file: trainA_testing3/0ce5101a-cc1645bd.pt
# Base key for image 652: 0ce5101a-cc1645bd
# Saving .pt file: trainA_testing3/0ce59f85-38ec2981.pt
# Base key for image 653: 0ce59f85-38ec2981
# Saving .pt file: trainA_testing3/0ce59f85-4636c80c.pt
# Base key for image 654: 0ce59f85-4636c80c
# Saving .pt file: trainA_testing3/0ce642e1-adcc9562.pt
# Base key for image 655: 0ce642e1-adcc9562
# Saving .pt file: trainA_testing3/0ce787d5-7656dfc2.pt
# Base key for image 656: 0ce787d5-7656dfc2
# Saving .pt file: trainA_testing3/0ce9abb1-04bba55e.pt
# Base key for image 657: 0ce9abb1-04bba55e
# Saving .pt file: trainA_testing3/0ce9abb1-857ab875.pt
# Base key for image 658: 0ce9abb1-857ab875
# Saving .pt file: trainA_testing3/0cfec061-210be3d5.pt
# Base key for image 659: 0cfec061-210be3d5
# Saving .pt file: trainA_testing3/0cfec061-4422030f.pt
# Base key for image 660: 0cfec061-4422030f
# Saving .pt file: trainA_testing3/0cfec584-8ab900db.pt
# Base key for image 661: 0cfec584-8ab900db
# Saving .pt file: trainA_testing3/0d01bff2-38b969d3.pt
# Base key for image 662: 0d01bff2-38b969d3
# Saving .pt file: trainA_testing3/0d0e2aee-eaac831f.pt
# Base key for image 663: 0d0e2aee-eaac831f
# Saving .pt file: trainA_testing3/0d0e69b6-507e6590.pt
# Base key for image 664: 0d0e69b6-507e6590
# Saving .pt file: trainA_testing3/0d0e69b6-a30b3acb.pt
# Base key for image 665: 0d0e69b6-a30b3acb
# Saving .pt file: trainA_testing3/0d0f5dd1-3fa53680.pt
# Base key for image 666: 0d0f5dd1-3fa53680
# Saving .pt file: trainA_testing3/0d1dd928-2d090841.pt
# Base key for image 667: 0d1dd928-2d090841
# Saving .pt file: trainA_testing3/0d1e09fe-f692552c.pt
# Base key for image 668: 0d1e09fe-f692552c
# Saving .pt file: trainA_testing3/0d1fc580-2bbf8587.pt
# Base key for image 669: 0d1fc580-2bbf8587
# Saving .pt file: trainA_testing3/0d1fc580-3be6937e.pt
# Base key for image 670: 0d1fc580-3be6937e
# Saving .pt file: trainA_testing3/0d1fc580-44142e94.pt
# Base key for image 671: 0d1fc580-44142e94
# Saving .pt file: trainA_testing3/0d1fc580-61bbac5d.pt
# Base key for image 672: 0d1fc580-61bbac5d
# Saving .pt file: trainA_testing3/0d1fc580-678ed420.pt
# Base key for image 673: 0d1fc580-678ed420
# Saving .pt file: trainA_testing3/0d2bc446-a829d9a5.pt
# Base key for image 674: 0d2bc446-a829d9a5
# Saving .pt file: trainA_testing3/0d2c8e1d-16f37059.pt
# Base key for image 675: 0d2c8e1d-16f37059
# Saving .pt file: trainA_testing3/0d2c8e1d-1cbddd28.pt
# Base key for image 676: 0d2c8e1d-1cbddd28
# Saving .pt file: trainA_testing3/0d2c8e1d-8993cc3e.pt
# Base key for image 677: 0d2c8e1d-8993cc3e
# Saving .pt file: trainA_testing3/0d2c8e1d-aebc65ec.pt
# Base key for image 678: 0d2c8e1d-aebc65ec
# Saving .pt file: trainA_testing3/0d2c8e1d-e81ed48e.pt
# Base key for image 679: 0d2c8e1d-e81ed48e
# Saving .pt file: trainA_testing3/0d2d0af8-19a7a53e.pt
# Base key for image 680: 0d2d0af8-19a7a53e
# Saving .pt file: trainA_testing3/0d2e77d4-507c02c4.pt
# Base key for image 681: 0d2e77d4-507c02c4
# Saving .pt file: trainA_testing3/0d2eaa9b-d7d07e80.pt
# Base key for image 682: 0d2eaa9b-d7d07e80
# Saving .pt file: trainA_testing3/0d3a2ed1-ac4b05e1.pt
# Base key for image 683: 0d3a2ed1-ac4b05e1
# Saving .pt file: trainA_testing3/0d3a4e7f-42aea218.pt
# Base key for image 684: 0d3a4e7f-42aea218
# Saving .pt file: trainA_testing3/0d3a4e7f-fa62521a.pt
# Base key for image 685: 0d3a4e7f-fa62521a
# Saving .pt file: trainA_testing3/0d3a8582-d018e1f6.pt
# Base key for image 686: 0d3a8582-d018e1f6
# Saving .pt file: trainA_testing3/0d3ec56a-f4cead6f.pt
# Base key for image 687: 0d3ec56a-f4cead6f
# Saving .pt file: trainA_testing3/0d4b627d-0fb6471c.pt
# Base key for image 688: 0d4b627d-0fb6471c
# Saving .pt file: trainA_testing3/0d4c18ab-aa3095bb.pt
# Base key for image 689: 0d4c18ab-aa3095bb
# Saving .pt file: trainA_testing3/0d4c18ab-bb0ea14f.pt
# Base key for image 690: 0d4c18ab-bb0ea14f
# Saving .pt file: trainA_testing3/0d4c18ab-ec5404b2.pt
# Base key for image 691: 0d4c18ab-ec5404b2
# Saving .pt file: trainA_testing3/0d4d66bf-2d327e43.pt
# Base key for image 692: 0d4d66bf-2d327e43
# Saving .pt file: trainA_testing3/0d5a4fa0-4d2d45e6.pt
# Base key for image 693: 0d5a4fa0-4d2d45e6
# Saving .pt file: trainA_testing3/0d5b19b3-8232a53f.pt
# Base key for image 694: 0d5b19b3-8232a53f
# Saving .pt file: trainA_testing3/0d5b19b3-95b6f539.pt
# Base key for image 695: 0d5b19b3-95b6f539
# Saving .pt file: trainA_testing3/0d5b19b3-df617a03.pt
# Base key for image 696: 0d5b19b3-df617a03
# Saving .pt file: trainA_testing3/0d5b19b3-e3f51851.pt
# Base key for image 697: 0d5b19b3-e3f51851
# Saving .pt file: trainA_testing3/0d5b19b3-fd1646ea.pt
# Base key for image 698: 0d5b19b3-fd1646ea
# Saving .pt file: trainA_testing3/0d5b19b3-fe488e51.pt
# Base key for image 699: 0d5b19b3-fe488e51

# %%
train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# %% [markdown]
# # RPN from Scratch

# %% [markdown]
# ## Embedding & Feature Extraction

# %%
class ResNetBackbone(nn.Module):
    def __init__(self, pretrained=True):
        super(ResNetBackbone, self).__init__()
        # Load Pretrain RESNET
        resnet = models.resnet50(pretrained=pretrained)

        # Remove the fully connected layers (we only need the feature extractor)
        self.backbone = nn.Sequential(*list(resnet.children())[:-2])

    def forward(self, x):
        # Forward pass through the backbone
        features = self.backbone(x)
        return features

# %% [markdown]
# ## Anchor Generator

# %%
def generate_base_anchors(scales, ratios, base_size=16):
    """
    Generate base anchor boxes in [x1, y1, x2, y2] format.
    """
    anchors = []
    for scale in scales:
        for ratio in ratios:
            # Compute width and height based on scale and aspect ratio.
            w = base_size * scale * np.sqrt(ratio)
            h = base_size * scale / np.sqrt(ratio)
            # intialize a square centered at the origin
            x1 = -w / 2.0
            y1 = -h / 2.0
            x2 = w / 2.0
            y2 = h / 2.0
            anchors.append([x1, y1, x2, y2])
    return np.array(anchors)

class AnchorGenerator:
    def __init__(self, scales=[8, 16, 32], ratios=[0.5, 1, 2], stride=16):
        self.scales = scales
        self.ratios = ratios
        self.base_anchors = generate_base_anchors(scales, ratios, base_size=stride)
        self.stride = stride

    def generate_anchors(self, feature_height, feature_width):
        """
        Generate all anchors for a feature map of size (feature_height, feature_width).
        Shifts the base anchors to all spatial locations in the feature map.
        """
        shift_x = torch.arange(0, feature_width * self.stride, step=self.stride, dtype=torch.float32)
        shift_y = torch.arange(0, feature_height * self.stride, step=self.stride, dtype=torch.float32)

        # Generate the 2D tensors (x,y)
        shift_y, shift_x = torch.meshgrid(shift_y, shift_x, indexing="ij")
        shifts = torch.stack((
            shift_x.reshape(-1),
            shift_y.reshape(-1),
            shift_x.reshape(-1),
            shift_y.reshape(-1)
        ), dim=1)

        base_anchors = torch.tensor(self.base_anchors, dtype=torch.float32)
        A = base_anchors.shape[0] # Number of base anchors
        K = shifts.shape[0] # Total number of positions in the feature map
        # Add the base anchors to each shift to generate all anchors.
        anchors = base_anchors.reshape(1, A, 4) + shifts.reshape(K, 1, 4)
        anchors = anchors.reshape(K * A, 4)
        return anchors

# %% [markdown]
# # IOU

# %%
def compute_iou(boxes1, boxes2):
    area1 = (boxes1[:, 2] - boxes1[:, 0]) * (boxes1[:, 3] - boxes1[:, 1])
    area2 = (boxes2[:, 2] - boxes2[:, 0]) * (boxes2[:, 3] - boxes2[:, 1])

    lt = torch.max(boxes1[:, None, :2], boxes2[:, :2])  # [N, M, 2]
    rb = torch.min(boxes1[:, None, 2:], boxes2[:, 2:])  # [N, M, 2]

    wh = (rb - lt).clamp(min=0)  # [N, M, 2]
    inter = wh[:, :, 0] * wh[:, :, 1]  # [N, M]

    union = area1[:, None] + area2 - inter
    iou = inter / union
    return iou
def assign_targets(anchors, gt_boxes, pos_iou_thresh=0.7, neg_iou_thresh=0.3):
    N = anchors.shape[0]
    labels = -1 * torch.ones((N,), dtype=torch.int64)
    iou = compute_iou(anchors, gt_boxes)
    max_iou, argmax_iou = iou.max(dim=1)
    labels[max_iou < neg_iou_thresh] = 0
    labels[max_iou >= pos_iou_thresh] = 1
    max_iou_per_gt, _ = iou.max(dim=0)
    for i in range(gt_boxes.shape[0]):
        inds = (iou[:, i] == max_iou_per_gt[i]).nonzero(as_tuple=False).view(-1)
        labels[inds] = 1
    bbox_targets = torch.zeros((N, 4), dtype=torch.float32)
    pos_inds = torch.nonzero(labels == 1, as_tuple=False).view(-1)
    if pos_inds.numel() > 0:
        assigned_gt = gt_boxes[argmax_iou[pos_inds]]
        anchors_pos = anchors[pos_inds]
        widths = anchors_pos[:, 2] - anchors_pos[:, 0]
        heights = anchors_pos[:, 3] - anchors_pos[:, 1]
        ctr_x = anchors_pos[:, 0] + 0.5 * widths
        ctr_y = anchors_pos[:, 1] + 0.5 * heights
        gt_widths = assigned_gt[:, 2] - assigned_gt[:, 0]
        gt_heights = assigned_gt[:, 3] - assigned_gt[:, 1]
        gt_ctr_x = assigned_gt[:, 0] + 0.5 * gt_widths
        gt_ctr_y = assigned_gt[:, 1] + 0.5 * gt_heights
        targets_dx = (gt_ctr_x - ctr_x) / widths
        targets_dy = (gt_ctr_y - ctr_y) / heights
        targets_dw = torch.log(gt_widths / widths)
        targets_dh = torch.log(gt_heights / heights)
        bbox_targets[pos_inds] = torch.stack((targets_dx, targets_dy, targets_dw, targets_dh), dim=1)
    return labels, bbox_targets

# %% [markdown]
# # RPN

# %%
class RPN(nn.Module):
    def __init__(self, in_channels, num_anchors=9):
        super(RPN, self).__init__()
        self.num_anchors = num_anchors
        self.conv = nn.Conv2d(in_channels, 512, kernel_size=3, stride=1, padding=1)
        self.objectness = nn.Conv2d(512, num_anchors * 2, kernel_size=1, stride=1)
        self.bbox_reg = nn.Conv2d(512, num_anchors * 4, kernel_size=1, stride=1)

    def forward(self, x):
        x = torch.relu(self.conv(x))
        objectness_scores = self.objectness(x)
        bbox_offsets = self.bbox_reg(x)
        return objectness_scores, bbox_offsets

# %%
class RCNN(nn.Module):
    def __init__(self, backbone, rpn, anchor_generator):
        super(RCNN, self).__init__()
        self.backbone = backbone
        self.rpn = rpn
        self.anchor_generator = anchor_generator

    def forward(self, x, gt_boxes=None):
        features = self.backbone(x)
        objectness_scores, bbox_offsets = self.rpn(features)
        _, _, feat_h, feat_w = features.shape
        device = features.device
        anchors = self.anchor_generator.generate_anchors(feat_h, feat_w)
        if self.training and gt_boxes is not None:
            labels, bbox_targets = assign_targets(anchors, gt_boxes)
            return objectness_scores, bbox_offsets, anchors, labels, bbox_targets
        return objectness_scores, bbox_offsets, anchors

# %%
def apply_bbox_offsets(anchors, bbox_offsets):
    """
    Apply predicted offsets to anchors to generate final bounding boxes.
    anchors: (N, 4)
    bbox_offsets: (N, 4)
    Returns: (N, 4) bounding boxes.
    """
    widths = anchors[:, 2] - anchors[:, 0]
    heights = anchors[:, 3] - anchors[:, 1]
    ctr_x = anchors[:, 0] + 0.5 * widths
    ctr_y = anchors[:, 1] + 0.5 * heights

    dx = bbox_offsets[:, 0]
    dy = bbox_offsets[:, 1]
    dw = bbox_offsets[:, 2]
    dh = bbox_offsets[:, 3]

    pred_ctr_x = dx * widths + ctr_x
    pred_ctr_y = dy * heights + ctr_y
    pred_w = torch.exp(dw) * widths
    pred_h = torch.exp(dh) * heights

    pred_boxes = torch.zeros_like(anchors)
    pred_boxes[:, 0] = pred_ctr_x - 0.5 * pred_w
    pred_boxes[:, 1] = pred_ctr_y - 0.5 * pred_h
    pred_boxes[:, 2] = pred_ctr_x + 0.5 * pred_w
    pred_boxes[:, 3] = pred_ctr_y + 0.5 * pred_h

    return pred_boxes

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# Hyperparameters
num_epochs = 10
learning_rate = 0.001
batch_size = 4

# Initialize model, optimizer, and loss functions
backbone = ResNetBackbone(pretrained=True)
rpn = RPN(in_channels=2048)  # ResNet-50 backbone outputs 2048 channels
anchor_generator = AnchorGenerator()
model = RCNN(backbone, rpn, anchor_generator)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
cls_criterion = nn.CrossEntropyLoss()  # For objectness classification
reg_criterion = nn.SmoothL1Loss()      # For bounding box regression


from torch.utils.data._utils.collate import default_collate

def custom_collate_fn(batch):
    images = [item[0] for item in batch]  # Extract images
    labels = [item[1] for item in batch]  # Extract label dictionaries

    # Stack images into a single tensor
    images = default_collate(images)

    # Collate labels manually
    collated_labels = {
        "boxes": default_collate([label["boxes"] for label in labels]),
        "labels": default_collate([label["labels"] for label in labels]),
        "names": [label["names"] for label in labels]  # Names remain as a list of lists
    }

    return images, collated_labels

# Create DataLoader with the custom collate function
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=custom_collate_fn)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, collate_fn=custom_collate_fn)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False, collate_fn=custom_collate_fn)

for images, gt_boxes in train_loader:
    print("Images shape:", images.shape)  # Should be [batch_size, 3, height, width]
    print("Boxes shape:", gt_boxes["boxes"].shape)  # Should be [batch_size, max_boxes, 4]
    print("Labels shape:", gt_boxes["labels"].shape)  # Should be [batch_size, max_boxes]
    print("Names:", gt_boxes["names"])  # Should be a list of lists of strings
    break

# Training loop
train_losses = []
train_ious = []

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    epoch_iou = 0.0

    for images, gt_boxes in train_loader:
        for images, gt_boxes in train_loader:
          images = images  # Images tensor of shape [batch_size, 3, height, width]
          boxes = gt_boxes["boxes"]  # Bounding boxes tensor of shape [batch_size, max_boxes, 4]
          labels = gt_boxes["labels"]  # Labels tensor of shape [batch_size, max_boxes]
          names = gt_boxes["names"]  # List of lists of strings

          # Ensure all gt_boxes have the same shape
          max_boxes = boxes.shape[1]  # Maximum number of boxes per image

          # Debug: Print shapes to verify
          print("Images shape:", images.shape)
          print("Boxes shape:", boxes.shape)
          print("Labels shape:", labels.shape)
          print("Names:", names)
        # Forward pass
        optimizer.zero_grad()
        objectness_scores, bbox_offsets, anchors, labels, bbox_targets = model(images, gt_boxes)

        # Reshape outputs
        objectness_scores = objectness_scores.permute(0, 2, 3, 1).reshape(-1, 2)  # (N * H * W * A, 2)
        bbox_offsets = bbox_offsets.permute(0, 2, 3, 1).reshape(-1, 4)            # (N * H * W * A, 4)

        # Compute classification loss
        cls_loss = cls_criterion(objectness_scores, labels)

        # Compute regression loss (only for positive anchors)
        pos_inds = torch.nonzero(labels == 1, as_tuple=False).squeeze(1)
        if pos_inds.numel() > 0:
            reg_loss = reg_criterion(bbox_offsets[pos_inds], bbox_targets[pos_inds])
        else:
            reg_loss = torch.tensor(0.0)

        # Total loss
        loss = cls_loss + reg_loss
        epoch_loss += loss.item()

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        # Compute IoU for evaluation
        with torch.no_grad():
            pred_boxes = apply_bbox_offsets(anchors, bbox_offsets)  # Convert offsets to boxes
            iou = compute_iou(pred_boxes[pos_inds], gt_boxes[pos_inds])  # Compare to ground truth
            epoch_iou += iou.mean().item()

    # Average loss and IoU for the epoch
    epoch_loss /= len(train_loader)
    epoch_iou /= len(train_loader)
    train_losses.append(epoch_loss)
    train_ious.append(epoch_iou)

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}, IoU: {epoch_iou:.4f}")
